# %% [markdown]
# The goal is to provide you with the tools that you would probably get if you were an actual quant at a big investment bank.
#
# I've never felt quant trading to be a zero-sum game. Publishing, peer review, and building on previous ideas has worked in the sciences and serves as a model for moving from 'quant arts' to 'quant science'. A rising tide can raise all ships.

# %% [markdown]
# |Pillars|Idea|Competitors|Competitive Advantage|
# |-------|----|------------|---------------------|
# |Educate|Synthesized the fundamentals of investing|Investopedia|Confusing where to start, as a lot of websites spread misinformation and disinformation or want to sell you a product<br />Little to no structure of the content, knowledge is spread across, often recycled, harder to identify streams of thought|
# |Research |Quantopian<br /> Got to give it to them, the Alphalens library is something that is hard to compete against, but still, check point below|
# |Design Strategies||Quantopian (probably the biggest competitor)<br />Available for retail traders, but only to those that understand the API and are familiar with Python and its libraries<br />Data is available but is encapsulated, user cannot directly access it<br />Impossibly hard to convert it to an actual trading algorithm<br />Lacks flexibility (i.e. ttm or not)
