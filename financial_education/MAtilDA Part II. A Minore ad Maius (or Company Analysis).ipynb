# %% [markdown]
# # Fundamental Analysis

# %% [markdown]
# ## Financial Statements

# %% [markdown]
# ### Income Statement (Statement of Operations)
#
#
# Various abbreviations may be used in financial statements, especially financial statements summarized on the Internet. Sales reported by a firm are usually net sales, which deduct returns, allowances, and early payment discounts from the charge on an invoice. Net income is always the amount after taxes, depreciation, amortization, and interest, unless otherwise stated. Otherwise, the amount would be EBIT, or EBITDA (see below).
#
# Companies that are primarily involved in providing services with labour do not generally report "Sales" based on hours. These companies tend to report "revenue" based on the monetary value of income that the services provide.
#
# Note that Shareholders' Equity and Owner's Equity are not the same thing, Shareholder's Equity represents the total number of shares in the company multiplied by each share's book value; Owner's Equity represents the total number of shares that an individual shareholder owns (usually the owner with controlling interest), multiplied by each share's book value. It is important to make this distinction when calculating ratios.
#
#
# COGS = Cost of goods sold, or cost of sales.
# EBIT = Earnings before interest and taxes
# EBITDA = Earnings before interest, taxes, depreciation, and amortization
# EPS = Earnings per share
#
#
# Operating income is the difference between operating revenues and operating expenses, but it is also sometimes used as a synonym for EBIT and operating profit.[10] This is true if the firm has no non-operating income. (Earnings before interest and taxes / Sales

# %% [markdown]
# ### Balance Sheet (Statement of Financial Condition)

# %% [markdown]
# ### Cash Flow Statement (Statements of Cash Flows)

# %% [markdown]
# ## Accounting Ratios

# %% [markdown]
# ### Profitability Ratios
#
# Profitability ratios measure the company's use of its assets and control of its expenses to generate an acceptable rate of return
#
# https://en.wikipedia.org/wiki/Gross_margin
# $$ \text{Gross Margin} = \frac{\text{Gross Profit}}{\text{Net Sales}} = \frac{\text{Net Sales - COGS}}{\text{Net Sales}} $$
#
# https://en.wikipedia.org/wiki/Operating_margin
# $$ \text{Operating Margin} = \frac{\text{Operating Income}}{\text{Net Sales}} $$
#
# https://en.wikipedia.org/wiki/Profit_margin
# $$ \text{Profit Margin} = \frac{\text{Net Profit}}{\text{Net Sales}} $$
#
# https://en.wikipedia.org/wiki/Return_on_equity
# https://en.wikipedia.org/wiki/Return_on_Equity_Du_Pont
# $$ \text{Return on Equity} = \frac{\text{Net Income}}{\text{Average Shareholders Equity}} = \frac{\text{Net Income}}{\text{Net Sales}} * \frac{\text{Net Sales}}{\text{Average Assets}} * \frac{\text{Average Assets}}{\text{Average Shareholders Equity}}$$
#
# https://en.wikipedia.org/wiki/Return_on_assets
# https://en.wikipedia.org/wiki/Return_on_assets_Du_Pont
# $$ \text{Return on Assets} = \frac{\text{Net Income}}{\text{Average Total Assets}} = \frac{\text{Net Income}}{\text{Net Sales}} * \frac{\text{Net Sales}}{\text{Total Assets}} $$
#
# https://en.wikipedia.org/wiki/Return_on_net_assets
# $$ \text{Return on Net Assets} = \frac{\text{Net Income}}{\text{Fixed Assets + Working Capital}} $$
#
# https://en.wikipedia.org/wiki/Return_on_capital
# $$ \text{Return on Capital} = \frac{\text{EBIT * (1 - Tax Rate)}}{\text{Invested Capital}} $$
#
# https://en.wikipedia.org/wiki/Risk_adjusted_return_on_capital
# $$ \text{Risk-Adjusted Return on Capital} = \frac{\text{Expected Return}}{\text{Economic Capital}} \text{ OR } \frac{\text{Expected Return}}{\text{Value at Risk}} $$
#
# https://en.wikipedia.org/wiki/Return_on_capital_employed
# $$ \text{Return on Capital Employed} = \frac{\text{EBIT}}{\text{Capital Employed}} $$
#
# https://en.wikipedia.org/wiki/Cash_flow_return_on_investment
# $$ \text{Cash Flow Return on Investment} = \frac{\text{Cash Flow}}{\text{Market Recapitalisation}} $$
#
# https://en.wikipedia.org/wiki/Efficiency_ratio
# $$ \text{Efficiency Ratio} = \frac{\text{Non-Interest Expense}}{\text{Revenue}} $$
#
# $$ \text{Net Gearing} = \frac{\text{Net Debt}}{\text{Equity}} $$
#
# $$ \text{Basic Earnings Power Ratio} = \frac{\text{EBIT}}{\text{Total Assets}} $$

# %% [markdown]
# ### Liquidity Ratios
#
# Liquidity ratios measure the availability of cash to pay debt.
#
# https://en.wikipedia.org/wiki/Current_ratio
# $$ \text{Current Ratio (Working Capital Ratio)} = \frac{\text{Current Assets}}{\text{Current Liabilities}} $$
#
# https://en.wikipedia.org/wiki/Quick_ratio
# $$ \text{Acid-Test Ratio (Quick Ratio)} = \frac{\text{Current Assets - (Inventories + Prepayments)}}{\text{Current Liabilities}} $$
#
# https://en.wikipedia.org/wiki/Cash_ratio
# $$ \text{Cash Ratio} = \frac{\text{Cash and Marketable Securities}}{\text{Current Liabilities}} $$
#
# https://en.wikipedia.org/wiki/Operating_cash_flow
# $$ \text{Operating Cash Flow Ratio} = \frac{\text{Operating Cash Flow}}{\text{Total Debts}} $$

# %% [markdown]
# ### Activity Ratios (Efficiency Ratios)
#
# Activity ratios measure the effectiveness of the firm's use of resources.
#
# https://en.wikipedia.org/wiki/Debtor_collection_period
# $$ \text{Average Collection Period} = \frac{\text{Accounts Receivable}}{\text{Annual Credit Sales} / \text{365 Days}} $$
#
# https://en.wikipedia.org/wiki/Operating_leverage#DOL_and_Operating_income
# $$ \text{Degree of Operating Leverage} = \frac{\text{Percent Change in Net Operating Income}}{\text{Percent Change in Sales}} $$
#
# https://en.wikipedia.org/wiki/DSO_Ratio
# $$ \text{Days Sales Outstanding (DSO) Ratio} = \frac{\text{Accounts Receivable}}{\text{Total Annual Sales} / \text{365 Days}} $$
#
# $$ \text{Average Payment Period} = \frac{\text{Accounts Payable}}{\text{Annual Credit Purchases} / \text{365 Days}} $$
#
# https://en.wikipedia.org/wiki/Asset_turnover
# $$ \text{Asset Turnover Ratio} = \frac{\text{Net Sales}}{\text{Total Assets}} $$
#
# https://en.wikipedia.org/wiki/Stock_turnover
# $$ \text{Inventory (Stock) Turnover Ratio} = \frac{\text{Cost of Goods Sold}}{\text{Average Inventory}} $$
#
# https://en.wikipedia.org/wiki/Receivables_Turnover_Ratio
# $$ \text{Receivables Turnover Ratio} = \frac{\text{Net Credit Sales}}{\text{Average Net Receivables}} $$
#
# $$ \text{Inventory Conversion Ratio} = \frac{\text{Inventory}}{\text{Cost of Goods Sold}} * \text{365 Days} = \frac{\text{365 Days}}{\text{Inventory Turnover}} $$
#
# $$ \text{Receivables Conversion Period} = \frac{\text{Receivables}}{\text{Net Sales}} * \text{365 Days} $$
#
# $$ \text{Payables Conversion Period} = \frac{\text{Accounts Payables}}{\text{Purchases}} * \text{365 Days} $$
#
# https://en.wikipedia.org/wiki/Cash_conversion_cycle
# $$ \text{Cash Conversion Cycle} = \text{Inventory Conversion Period} + \text{Receivables Conversion Period} + \text{Payables Conversion Period} $$

# %% [markdown]
# ### Debt Ratios (Leverage Ratios)
#
# $$ \text{Debt Ratio} = \frac{\text{Total Liabilities}}{\text{Total Assets}} $$
#
# $$ \text{Debt to Equity Ratio} = \frac{\text{Long-term Debt + Value of Leases}}{\text{Average Shareholders Equity}} $$
#
# $$ \text{Long-term Debt to Equity} = \frac{\text{Long-term Debt}}{\text{Average Shareholders Equity}} $$
#
# $$ \text{Times Interest Earned Ratio (Interest Coverage Ratio)} = \frac{\text{EBIT}}{\text{Annual Interest Expense}} \text{ OR } \frac{\text{Net Income}}{\text{Annual Interest Expense}} $$
#
# $$ \text{Debt Service Coverage Ratio} = \frac{\text{Net Operating Income}}{\text{Total Debt Service}} $$

# %% [markdown]
# ### Market Ratios
#
# Market ratios measure investor response to owning a company's stock and also the cost of issuing stock. These are concerned with the return on investment for shareholders, and with the relationship between return and the value of an investment in company's shares.
#
# $$ \text{Earnings per Share (EPS)} = \frac{\text{Net Earnings}}{\text{Number of Shares}} $$
#
# $$ \text{Payout Ratio} = \frac{\text{Dividends}}{\text{Earnings}} \text{ OR } \frac{\text{Dividends}}{\text{EPS}}$$
#
# $$ \text{Dividend Cover} = \frac{\text{EPS}}{\text{Dividend per Share}} $$
#
# $$ \text{Price to Earnings Ratio (P/E)} = \frac{\text{Market Price per Share}}{\text{Diluted EPS}} $$
#
# $$ \text{Dividend Yield} = \frac{\text{Dividend}}{\text{Current Market Price}} $$
#
# $$ \text{Price to Cash Flow Ratio} = \frac{\text{Market Price per Share}}{\text{Present Value of Cash Flow per Share}} $$
#
# $$ \text{Price to Book Value Ratio (P/B or PBV)} = \frac{\text{Market Price per Share}}{\text{Balance Sheet Price per Share}} $$
#
# $$ \text{Price to Sales Ratio (P/S)} = \frac{\text{Market Price per Share}}{\text{Gross Sales}} $$
#
# $$ \text{Price to Earnings to Growth Ratio (PEG)} = \frac{\text{Price to Earnings}}{\text{Annual EPS Growth}} $$
#
# $$ \text{EV/EBITDA} = \frac{\text{Enterprise Value}}{\text{EBITDA}} $$
#
# $$ \text{EV/Sales} = \frac{\text{Enterprise Value}}{\text{Net Sales}} $$

# %% [markdown]
# Financial ratios may not be directly comparable between companies that use different accounting methods or follow various standard accounting practices. Most public companies are required by law to use generally accepted accounting principles for their home countries, but private companies, partnerships and sole proprietorships may not use accrual basis accounting. Large multi-national corporations may use International Financial Reporting Standards to produce their financial statements, or they may use the generally accepted accounting principles of their home country.
#
# There is no international standard for calculating the summary data presented in all financial statements, and the terminology is not always consistent between companies, industries, countries and time periods.

# %% [markdown]
# ## Valuation Models

# %% [markdown]
# ## Other Models to Consider

# %% [markdown]
# ### Decomposition Models

# %% [markdown]
# #### Dupont Analysis

# %% [markdown]
# ### Financial Health (Default Prediction) Models

# %% [markdown]
# #### Piotroski's F-Score

# %% [markdown]
# #### Altman's Z-Score

# %% [markdown]
# #### Ohlson's O-Score

# %% [markdown]
# ### Earnings Manipulation Models

# %% [markdown]
# #### Beneish's M-Score

# %% [markdown]
# #### Montier's C-Score

# %% [markdown]
# # Technical Analysis

# %% [markdown]
# ## Technical Indicators
#
# Technical indicators are used by traders to gain insight into the supply and demand of securities and market psychology. Together, these indicators form the basis of technical analysis. Metrics, such as trading volume, provide clues as to whether a price move will continue. In this way, indicators can be used to generate buy and sell signals
#
# Some of these consider price history, others look at trading volume, and yet others are momentum indicators. Often, these are used in tandem or combination with one another.
#
# The tools of the trade for day traders and technical analysts consist of charting tools that generate signals to buy or sell, or which indicate trends or patterns in the market. Broadly speaking, there are two basic types of technical indicators:
#
# - **Overlays:** Technical indicators that use the same scale as prices are plotted over the top of the prices on a stock chart. Examples include moving averages and Bollinger Bands® or Fibonacci lines.
# - **Oscillators:** Rather than being overlayed on a price chart, technical indicators that oscillate between a local minimum and maximum are plotted above or below a price chart. Examples include the stochastic oscillator, MACD or RSI. It will mainly be these second kind of technical indicators that we consider in this article.

# %% [markdown]
# ### Volume Indicators

# %% [markdown]
# #### Accumulation/Distribution Index (ADI)
#
# $$ \text{A/D} = \text{Previous A/D} + \text{CMFV} $$
# where,
# * $ \text{CMFV} = \text{Current Money Flow Volume} = \frac{(P_C - P_L) - (P_H - P_C)}{P_H - P_L}$
# * $ P_C $ is the closing price.
# * $ P_L $ is the low price for the period.
# * $ P_H $ is the high price for the period.
# * $ V $ is the volume for the period.

# %% [markdown]
# #### On-Balance Volume (OBV)
#
# $$ \text{OBV} = \text{OBV}_{prev} +
# \left. \begin{array}{l}
# \textrm{volume, if close > close_prev}\\
# \textrm{0, if close = close_prev}\\
# \textrm{-volume, if close < close_prev}
# \end{array} \right\}
# $$
#
# where
# - $OBV$ is the current on-balance volume level
# - $OBV_{prev} $ is the previous on-balance volume level
# - $volume$ is the latest trading volume amount

# %% [markdown]
# #### Chaikin Money Flow (CMF)

# %% [markdown]
# #### Force Index (FI)

# %% [markdown]
# #### Ease of Movement (EoM, EMV)

# %% [markdown]
# #### Volume-price Trend (VPT)

# %% [markdown]
# #### Negative Volume Index (NVI)

# %% [markdown]
# #### Volume Weighted Average Price (VWAP)

# %% [markdown]
# ### Volatility Indicators

# %% [markdown]
# #### Average True Range (ATR)

# %% [markdown]
# #### Bollinger Bands (BB)
#
# $$ \text{BOLU} = \text{MA}(\text{TP}, n) + m * \sigma[\text{TP}, n] $$
# $$ \text{BOLD} = \text{MA}(\text{TP}, n) - m * \sigma[\text{TP}, n] $$
# where,
# - $\text{MA}$ is the moving average
# - $\text{TP}$ is the typical price i.e. $\frac{\text{(High + Low + Close)}}{3}$
# - $n$ is the number of days in smoothing period (typically 20)
# - $m$ is the number of standard deviations (typically 2)
# - $\sigma[\text{TP}, n]$ is the standard deviation over the last $n$ periods of TP

# %% [markdown]
# #### Keltner Channel (KC)

# %% [markdown]
# #### Donchian Channel (DC)

# %% [markdown]
# ### Trend Indicators

# %% [markdown]
# #### Moving Averages
#
# |MA Type|Name|
# |-------|----|
# |SMA|Simple Moving Average|
# |EMA|Exponential Moving Average|
# |WMA|Weighted Moving Average|
# |DEMA|Double Exponential Moving Average|
# |TEMA|Triple Exponential Moving Average|
# |KAMA|Kaufman Adaptive Moving Average|
# |MAMA|MESA Adaptive Moving Average|
# |T3|Triple Exponential Moving Average|

# %% [markdown]
# #### Moving Average Convergence Divergence (MACD)

# %% [markdown]
# #### Average Directional Movement Index (ADX)

# %% [markdown]
# #### Vortex Indicator (VI)

# %% [markdown]
# #### Trix (TRIX)

# %% [markdown]
# #### Mass Index (MI)

# %% [markdown]
# #### Commodity Channel Index (CCI)

# %% [markdown]
# #### Detrended Price Oscillator (DPO)

# %% [markdown]
# #### KST Oscillator (KST)

# %% [markdown]
# #### Ichimoku Kinkō Hyō (Ichimoku)

# %% [markdown]
# #### Parabolic Stop And Reverse (Parabolic SAR)

# %% [markdown]
# ### Momentum Indicators
#
# #### Money Flow Index (MFI)
#
# #### Relative Strength Index (RSI)
#
# #### True strength index (TSI)
#
# #### Ultimate Oscillator (UO)
#
# #### Stochastic Oscillator (SR)
#
# #### Williams %R (WR)
#
# #### Awesome Oscillator (AO)
#
# #### Kaufman's Adaptive Moving Average (KAMA)
#
# #### Rate of Change (ROC)
